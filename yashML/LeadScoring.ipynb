# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data = pd.read_csv("input/contacts.csv")
data.head(6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (2,13,25,26,28,30,33,35,36,37,39,55,56,60,62,65,67,75,76,77,78,84,85,86,87,89,90,91,92,93,94,95,96,97,98,99,103,104,115,122,123,135,136,177,186,187,189,190,191,192,222,249,250) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                               Email  Annual License Fee Estimate  \
# 0            test-57732@example.com                          NaN
# 1              margeaux@hippofm.com                          NaN
# 2               mphathi26@gmail.com                          NaN
# 3            akitzis@jfcsboston.org                          NaN
# 4            bawafi@anjumhotels.com                          NaN
# 5  paullangdon@citizenadvocates.net                          NaN
#
#   Are you currently using maintenance software?  Associated Deals  \
# ...

# %%
data.isnull().sum()
# Out:
# Email                                                                      0
# Annual License Fee Estimate                                            12543
# Are you currently using maintenance software?                          12608
# Associated Deals                                                       10215
# Country                                                                 5454
# Country Limited                                                         2026
# Currently in Sequence                                                  12671
# Days To Close                                                          11908
# Features Required:                                                     10809
# First Deal Created Date                                                10215
# Forms Filled                                                           10998
# How many buildings / sites?                                            11301
# ...

# %%
data.info()
# data['Are you currently using maintenance software?'].unique()
data.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12671 entries, 0 to 12670
# Columns: 302 entries, Email to Client Stage
# dtypes: float64(74), int64(11), object(217)
# memory usage: 29.2+ MB
#                            Email  Annual License Fee Estimate  \
# 12666  dominic@a5hospitality.com                          NaN
# 12667          jeremycvt@msn.com                          NaN
# 12668          dantosh@wcb.mb.ca                          NaN
# 12669      krishopkins@gmail.com                          NaN
# 12670   mikes@cityofatchison.com                          NaN
#
#       Are you currently using maintenance software?  Associated Deals Country  \
# 12666                                           NaN               NaN     NaN
# 12667                                           NaN               NaN     NaN
# 12668                                           NaN               NaN     NaN
# 12669                                           NaN               NaN     NaN
# ...

# %%
data.describe()
# Out:
#        Annual License Fee Estimate  Associated Deals  Currently in Sequence  \
# count                   128.000000       2456.000000                    0.0
# mean                   2623.296875          1.038681                    NaN
# std                    2345.356721          0.249909                    NaN
# min                       0.000000          1.000000                    NaN
# 25%                    1725.000000          1.000000                    NaN
# 50%                    1990.000000          1.000000                    NaN
# 75%                    3105.000000          1.000000                    NaN
# max                   24500.000000          7.000000                    NaN
#
#        Days To Close  Lead Status  Onboarding Fee Estimate  \
# count     763.000000          0.0               128.000000
# mean       77.470511          NaN              1158.101562
# std       131.002274          NaN               880.437050
# ...

# %%
data.corr()
# Out:
#                                                     Annual License Fee Estimate  \
# Annual License Fee Estimate                                            1.000000
# Associated Deals                                                            NaN
# Currently in Sequence                                                       NaN
# Days To Close                                                         -0.258627
# Lead Status                                                                 NaN
# Onboarding Fee Estimate                                                0.786098
# Recent Deal Amount                                                     0.570700
# Recent Sales Email Clicked Date                                             NaN
# Recent Sales Email Opened Date                                              NaN
# Recent Sales Email Replied Date                                             NaN
# Total Revenue                                                          0.570700
# ...

# %%
# print(__doc__)

# import matplotlib.pyplot as plt
# from sklearn.svm import SVC
# from sklearn.model_selection import StratifiedKFold
# from sklearn.feature_selection import RFECV
# from sklearn.datasets import make_classification

# # Build a classification task using 3 informative features
# X, y = make_classification(n_samples=3000, n_features=25, n_informative=3,
#                            n_redundant=2, n_repeated=0, n_classes=8,
#                            n_clusters_per_class=1, random_state=0)

# # Create the RFE object and compute a cross-validated score.
# svc = SVC(kernel="linear")
# # The "accuracy" scoring is proportional to the number of correct
# # classifications
# rfecv = RFECV(estimator=svc, step=1, cv=StratifiedKFold(2),
#               scoring='accuracy')
# rfecv.fit(X, y)

# print("Optimal number of features : %d" % rfecv.n_features_)

# # Plot number of features VS. cross-validation scores
# plt.figure()
# plt.xlabel("Number of features selected")
# plt.ylabel("Cross validation score (nb of correct classifications)")
# plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
# plt.show()

# %%
# from sklearn.ensemble import RandomForestClassifier
# # # from sklearn.datasets import make_classification
# # def data_random_forest(data):
# #     X, y = data(n_samples=1000, n_features=4,
# #                                n_informative=2, n_redundant=0,
# #                                random_state=0, shuffle=False)
# #     clf = RandomForestClassifier(max_depth=2, random_state=0)
# #     clf.fit(X, y)
# #     print(clf.feature_importances_)
# # data = pd.read_csv("input/contacts.csv")
# # data_random_forest(data)
# model = RandomForestClassifier(n_estimators=100)
# predictor_var = ['Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Loan_Amount_Term', 'Credit_History', 'Property_Area',
#         'LoanAmount_log','TotalIncome_log']
# classification_model(model, df,predictor_var,outcome_var)

# %%
#Import models from scikit learn module:
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
df = pd.read_csv("input/contacts.csv")

#Generic function for making a classification model and accessing performance:
def classification_model(model, data, predictors, outcome):
  #Fit the model:
  model.fit(data[predictors],data[outcome])
  
  #Make predictions on training set:
  predictions = model.predict(data[predictors])
  
  #Print accuracy
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print ("Accuracy : %s" % "{0:.3%}".format(accuracy))

  #Perform k-fold cross-validation with 5 folds
  kf = KFold(data.shape[0], n_folds=5)
  error = []
  for train, test in kf:
    # Filter training data
    train_predictors = (data[predictors].iloc[train,:])
    
    # The target we're using to train the algorithm.
    train_target = data[outcome].iloc[train]
    
    # Training the algorithm using the predictors and target.
    model.fit(train_predictors, train_target)
    
    #Record error from each cross-validation run
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
  print ("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))

  #Fit the model again so that it can be refered outside the function:
  model.fit(data[predictors],data[outcome]) 


    
model = RandomForestClassifier(n_estimators=100)
predictor_var = ['Days To Close', 'Lead Status']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (2,13,25,26,28,30,33,35,36,37,39,55,56,60,62,65,67,75,76,77,78,84,85,86,87,89,90,91,92,93,94,95,96,97,98,99,103,104,115,122,123,135,136,177,186,187,189,190,191,192,222,249,250) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-d0b70fb40cf4> in <module>()
#      45 model = RandomForestClassifier(n_estimators=100)
#      46 predictor_var = ['Days To Close', 'Lead Status']
# ---> 47 classification_model(model, df,predictor_var,outcome_var)
#
# NameError: name 'outcome_var' is not defined
